# %%
import pandas as pd
pd.set_option("display.max_columns", None)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pickle
sns.set_theme(style="whitegrid")

# %%
df = pd.read_pickle('../Data/df_teams.pkl')
df.head(10)
# Out:
#                   W    R    AB     H   2B  3B   HR     BB      SO     SB  \
# yearID franchID
# 2000   ANA       82  864  5628  1574  309  34  236  608.0  1024.0   93.0
#        ARI       85  792  5527  1466  282  44  179  535.0   975.0   97.0
#        ATL       95  810  5489  1490  274  26  179  595.0  1010.0  148.0
#        BAL       74  794  5549  1508  310  22  184  558.0   900.0  126.0
#        BOS       85  792  5630  1503  316  32  167  611.0  1019.0   43.0
#        CHW       95  978  5646  1615  325  33  216  591.0   960.0  119.0
#        CHC       65  764  5577  1426  272  23  183  632.0  1120.0   93.0
#        CIN       85  825  5635  1545  302  36  200  559.0   995.0  100.0
#        CLE       90  950  5683  1639  310  30  221  685.0  1057.0  113.0
#        COL       82  968  5660  1664  320  53  161  601.0   907.0  131.0
#
#                    SF   RA   ER   ERA  CG  SHO  SV    HA  HRA  BBA   SOA    E  \
# yearID franchID
# 2000   ANA       43.0  869  805  5.00   5    3  46  1534  228  662   846  134
#        ARI       58.0  754  698  4.35  16    8  38  1441  190  500  1220  107
#        ATL       45.0  714  648  4.05  13    9  53  1428  165  484  1093  129
#        BAL       54.0  913  855  5.37  14    6  33  1547  202  665  1017  116
#        BOS       48.0  745  683  4.23   7   12  46  1433  173  498  1121  109
#        CHW       61.0  839  751  4.66   5    7  43  1509  195  614  1037  133
#        CHC       45.0  904  849  5.25  10    5  39  1505  231  658  1143  100
#        CIN       58.0  765  700  4.33   8    7  42  1446  190  659  1015  111
#        CLE       52.0  816  775  4.84   6    5  34  1511  173  666  1213   72
#        COL       75.0  897  835  5.26   7    2  33  1568  221  588  1001   94
#
#                   DP     FP  BPF  PPF  DivWin_Y  WCWin_Y  LgWin_Y  WSWin_Y  \
# yearID franchID
# 2000   ANA       182  0.978  102  103         0        0        0        0
#        ARI       138  0.982  105  103         0        0        0        0
#        ATL       138  0.979  101   99         1        0        0        0
#        BAL       151  0.981   95   96         0        0        0        0
#        BOS       120  0.982  104  103         0        0        0        0
#        CHW       190  0.978  102  102         1        0        0        0
#        CHC       139  0.983   97   98         0        0        0        0
#        CIN       156  0.982  102  102         0        0        0        0
#        CLE       147  0.988  101  100         0        0        0        0
#        COL       176  0.985  125  125         0        0        0        0
#
#                  run_diff        ba
# yearID franchID
# 2000   ANA             -5  0.279673
#        ARI             38  0.265243
#        ATL             96  0.271452
#        BAL           -119  0.271761
#        BOS             47  0.266963
#        CHW            139  0.286043
#        CHC           -140  0.255693
#        CIN             60  0.274179
#        CLE            134  0.288404
#        COL             71  0.293993

# %%
df.reset_index(inplace=True)

# %%
df.describe()
# Out:
#             yearID          W           R           AB            H  \
# count   600.000000  600.00000  600.000000   600.000000   600.000000
# mean   2009.500000   80.97000  740.668333  5539.850000  1437.898333
# std       5.771093   11.78646   83.211830    77.610802    82.657537
# min    2000.000000   43.00000  513.000000  5294.000000  1199.000000
# 25%    2004.750000   72.00000  684.000000  5486.000000  1376.750000
# 50%    2009.500000   81.00000  735.000000  5538.000000  1435.000000
# 75%    2014.250000   90.00000  795.250000  5590.500000  1495.000000
# max    2019.000000  116.00000  978.000000  5770.000000  1667.000000
#
#                2B          3B          HR          BB           SO  \
# count  600.000000  600.000000  600.000000  600.000000   600.000000
# mean   287.165000   29.661667  173.465000  522.043333  1164.465000
# std     27.724818    8.922437   36.866208   70.176559   162.150589
# min    201.000000    5.000000   91.000000  363.000000   805.000000
# 25%    269.000000   23.000000  148.000000  471.000000  1043.000000
# 50%    286.000000   29.000000  170.000000  521.000000  1147.500000
# 75%    304.000000   35.000000  199.000000  566.250000  1276.250000
# max    376.000000   61.000000  307.000000  775.000000  1595.000000
#
#                SB          SF          RA          ER         ERA          CG  \
# count  600.000000  600.000000  600.000000  600.000000  600.000000  600.000000
# mean    92.008333   43.686667  740.668333  681.950000    4.248000    4.633333
# std     30.065065    8.594859   88.933948   82.619231    0.534891    3.334780
# min     19.000000   24.000000  525.000000  478.000000    2.940000    0.000000
# 25%     69.000000   37.750000  676.750000  621.750000    3.860000    2.000000
# 50%     89.000000   43.000000  733.000000  677.000000    4.205000    4.000000
# 75%    112.000000   49.000000  804.000000  737.500000    4.602500    7.000000
# max    200.000000   75.000000  981.000000  913.000000    5.710000   18.000000
#
#              SHO          SV           HA         HRA         BBA  \
# count  600.00000  600.000000   600.000000  600.000000  600.000000
# mean     9.38000   40.813333  1437.898333  173.465000  522.043333
# std      3.90611    7.280121    91.861702   29.337176   65.085649
# min      1.00000   23.000000  1125.000000   96.000000  348.000000
# 25%      7.00000   36.000000  1373.000000  153.000000  477.000000
# 50%      9.00000   41.000000  1439.000000  171.000000  520.500000
# 75%     12.00000   46.000000  1502.000000  191.000000  566.000000
# max     23.00000   66.000000  1683.000000  305.000000  728.000000
#
#                SOA           E          DP          FP         BPF  \
# count   600.000000  600.000000  600.000000  600.000000  600.000000
# mean   1164.465000  100.380000  147.558333    0.983415  100.148333
# std     160.036991   16.311828   18.099703    0.002640    5.297462
# min     764.000000   54.000000   95.000000    0.976000   88.000000
# 25%    1046.750000   88.750000  135.000000    0.982000   97.000000
# 50%    1153.000000  100.000000  147.000000    0.983000  100.000000
# 75%    1261.250000  110.000000  160.000000    0.985000  103.000000
# max    1687.000000  145.000000  204.000000    0.991000  125.000000
#
#               PPF    DivWin_Y     WCWin_Y     LgWin_Y     WSWin_Y    run_diff  \
# count  600.000000  600.000000  600.000000  600.000000  600.000000  600.000000
# mean   100.145000    0.200000    0.093333    0.066667    0.033333    0.000000
# std      5.213054    0.400334    0.291142    0.249652    0.179655  111.107116
# min     88.000000    0.000000    0.000000    0.000000    0.000000 -337.000000
# 25%     97.000000    0.000000    0.000000    0.000000    0.000000  -87.000000
# 50%    100.000000    0.000000    0.000000    0.000000    0.000000    2.000000
# 75%    103.000000    0.000000    0.000000    0.000000    0.000000   81.250000
# max    125.000000    1.000000    1.000000    1.000000    1.000000  300.000000
#
#                ba
# count  600.000000
# mean     0.259439
# std      0.012156
# min      0.226483
# 25%      0.250249
# 50%      0.259377
# 75%      0.267797
# max      0.293993

# %%
wins_df = df.groupby(['franchID'])['W'].mean()

# %% [markdown]
# # Which team has averaged the most amount of wins over the past 20 years?

# %% [markdown]
# As a Mets fan, I begrudgingly hypothesize that the Yankees is our answer.

# %%
wins_df = pd.DataFrame(wins_df).sort_values('W', ascending=False)
wins_df
# Out:
#               W
# franchID
# NYY       94.30
# STL       90.60
# BOS       89.60
# LAD       89.05
# ATL       86.75
# OAK       86.45
# ANA       86.10
# SFG       83.80
# CLE       83.55
# PHI       81.85
# MIN       81.40
# CHC       81.20
# HOU       81.05
# TEX       80.95
# NYM       80.40
# CHW       80.00
# TOR       79.95
# ARI       79.90
# SEA       79.75
# WSN       79.50
# MIL       78.25
# TBD       77.70
# CIN       76.30
# COL       76.05
# FLA       75.90
# DET       75.55
# SDP       75.40
# PIT       73.65
# BAL       72.65
# KCR       71.50

# %%
fig,ax = plt.subplots(figsize=(16,10))
ax = sns.barplot(x=wins_df.index, y='W', data=wins_df, palette='Blues_d')
ax.set_title("Average Regular Season Wins: P20Years", fontsize=18)
ax.set(xlabel='Franchise', ylabel='Wins')
plt.show()
plt.savefig('./Images_and_Analysis/P20Y_AvgRegSeasonWins.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-64e2df3c0fd5> in <module>
#       4 ax.set(xlabel='Franchise', ylabel='Wins')
#       5 plt.show()
# ----> 6 plt.savefig('./Images_and_Analysis/P20Y_AvgRegSeasonWins.png')
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# ~\anaconda3\envs\learn-env\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './Images_and_Analysis/P20Y_AvgRegSeasonWins.png'

# %% [markdown]
# # What about past 5 years?

# %%
# filter db to P5Years, 2015 - 2019
df_p5y = df.loc[(df['yearID']>2014)]
df_p5y
# Out:
#      yearID franchID   W    R    AB     H   2B  3B   HR     BB      SO     SB  \
# 450    2015      ARI  79  720  5649  1494  289  48  154  490.0  1312.0  132.0
# 451    2015      ATL  67  573  5420  1361  251  18  100  471.0  1107.0   69.0
# 452    2015      BAL  81  713  5485  1370  246  20  217  418.0  1331.0   44.0
# 453    2015      BOS  78  748  5640  1495  294  33  161  478.0  1148.0   71.0
# 454    2015      CHW  76  622  5533  1381  260  27  136  404.0  1231.0   68.0
# ..      ...      ...  ..  ...   ...   ...  ...  ..  ...    ...     ...    ...
# 595    2019      STL  91  764  5449  1336  246  24  210  561.0  1420.0  116.0
# 596    2019      TBD  96  769  5628  1427  291  29  217  542.0  1493.0   94.0
# 597    2019      TEX  78  810  5540  1374  296  24  223  534.0  1578.0  131.0
# 598    2019      TOR  67  726  5493  1299  270  21  247  509.0  1514.0   51.0
# 599    2019      WSN  93  873  5512  1460  298  27  231  584.0  1308.0  116.0
#
#        SF   RA   ER   ERA  CG  SHO  SV    HA  HRA  BBA   SOA    E   DP     FP  \
# 450  57.0  713  659  4.04   1   12  44  1450  182  500  1215   86  146  0.986
# 451  31.0  760  698  4.41   3   10  44  1462  170  550  1148   90  186  0.985
# 452  32.0  693  646  4.05   0   10  43  1406  174  483  1233   77  134  0.987
# 453  42.0  753  694  4.31   3   10  40  1486  178  478  1218   97  148  0.984
# 454  37.0  701  643  3.98   7    9  37  1443  162  474  1359  101  159  0.983
# ..    ...  ...  ...   ...  ..  ...  ..   ...  ...  ...   ...  ...  ...    ...
# 595  39.0  662  609  3.80   1   14  52  1284  191  545  1399   66  168  0.989
# 596  34.0  656  598  3.65   0   12  46  1274  181  453  1621   87  126  0.985
# 597  44.0  878  808  5.06   4    9  33  1515  241  583  1379  105  143  0.982
# 598  28.0  828  767  4.79   1    7  33  1450  228  604  1332   96  141  0.984
# 599  42.0  724  683  4.27   1   13  40  1340  202  517  1511   87  111  0.985
#
#      BPF  PPF  DivWin_Y  WCWin_Y  LgWin_Y  WSWin_Y  run_diff        ba
# 450  107  106         0        0        0        0         7  0.264472
# 451   97   97         0        0        0        0      -187  0.251107
# 452  103  104         0        0        0        0        20  0.249772
# 453  104  107         0        0        0        0        -5  0.265071
# 454   92   93         0        0        0        0       -79  0.249593
# ..   ...  ...       ...      ...      ...      ...       ...       ...
# 595   98   97         1        0        0        0       102  0.245183
# 596   97   96         0        1        0        0       113  0.253554
# 597  111  112         0        0        0        0       -68  0.248014
# 598   97   98         0        0        0        0      -102  0.236483
# 599  106  104         0        1        1        1       149  0.264877
#
# [150 rows x 34 columns]

# %%
df_p5y_grouped = df_p5y.groupby(['franchID'])['W'].mean()

# %%
df_p5y_grouped = pd.DataFrame(df_p5y_grouped).sort_values('W', ascending=False)
df_p5y_grouped
# Out:
#              W
# franchID
# LAD       97.0
# HOU       96.2
# CHC       94.2
# NYY       93.0
# CLE       92.2
# BOS       91.2
# WSN       90.0
# STL       89.6
# TBD       82.8
# MIL       82.4
# NYM       82.0
# ARI       81.6
# MIN       81.2
# TEX       81.2
# OAK       81.2
# PIT       80.4
# TOR       79.6
# SEA       79.4
# ATL       78.8
# COL       78.4
# ANA       78.2
# SFG       77.0
# KCR       74.6
# PHI       72.2
# CHW       71.0
# SDP       69.8
# FLA       69.4
# BAL       69.2
# CIN       68.4
# DET       67.0

# %%
# P5Years
fig,ax = plt.subplots(figsize=(16,10))
ax = sns.barplot(x=df_p5y_grouped.index, y='W', data=df_p5y_grouped, palette='Blues_d')
ax.set_title("Average Regular Season Wins: P5Years", fontsize=18)
ax.set(xlabel='Franchise', ylabel='Wins')
plt.show()
plt.savefig('../Images_and_Analysis/P5Y_AvgRegSeasonWins.png')

# %%
df.describe()
# Out:
#             yearID          W           R           AB            H  \
# count   600.000000  600.00000  600.000000   600.000000   600.000000
# mean   2009.500000   80.97000  740.668333  5539.850000  1437.898333
# std       5.771093   11.78646   83.211830    77.610802    82.657537
# min    2000.000000   43.00000  513.000000  5294.000000  1199.000000
# 25%    2004.750000   72.00000  684.000000  5486.000000  1376.750000
# 50%    2009.500000   81.00000  735.000000  5538.000000  1435.000000
# 75%    2014.250000   90.00000  795.250000  5590.500000  1495.000000
# max    2019.000000  116.00000  978.000000  5770.000000  1667.000000
#
#                2B          3B          HR          BB           SO  \
# count  600.000000  600.000000  600.000000  600.000000   600.000000
# mean   287.165000   29.661667  173.465000  522.043333  1164.465000
# std     27.724818    8.922437   36.866208   70.176559   162.150589
# min    201.000000    5.000000   91.000000  363.000000   805.000000
# 25%    269.000000   23.000000  148.000000  471.000000  1043.000000
# 50%    286.000000   29.000000  170.000000  521.000000  1147.500000
# 75%    304.000000   35.000000  199.000000  566.250000  1276.250000
# max    376.000000   61.000000  307.000000  775.000000  1595.000000
#
#                SB          SF          RA          ER         ERA          CG  \
# count  600.000000  600.000000  600.000000  600.000000  600.000000  600.000000
# mean    92.008333   43.686667  740.668333  681.950000    4.248000    4.633333
# std     30.065065    8.594859   88.933948   82.619231    0.534891    3.334780
# min     19.000000   24.000000  525.000000  478.000000    2.940000    0.000000
# 25%     69.000000   37.750000  676.750000  621.750000    3.860000    2.000000
# 50%     89.000000   43.000000  733.000000  677.000000    4.205000    4.000000
# 75%    112.000000   49.000000  804.000000  737.500000    4.602500    7.000000
# max    200.000000   75.000000  981.000000  913.000000    5.710000   18.000000
#
#              SHO          SV           HA         HRA         BBA  \
# count  600.00000  600.000000   600.000000  600.000000  600.000000
# mean     9.38000   40.813333  1437.898333  173.465000  522.043333
# std      3.90611    7.280121    91.861702   29.337176   65.085649
# min      1.00000   23.000000  1125.000000   96.000000  348.000000
# 25%      7.00000   36.000000  1373.000000  153.000000  477.000000
# 50%      9.00000   41.000000  1439.000000  171.000000  520.500000
# 75%     12.00000   46.000000  1502.000000  191.000000  566.000000
# max     23.00000   66.000000  1683.000000  305.000000  728.000000
#
#                SOA           E          DP          FP         BPF  \
# count   600.000000  600.000000  600.000000  600.000000  600.000000
# mean   1164.465000  100.380000  147.558333    0.983415  100.148333
# std     160.036991   16.311828   18.099703    0.002640    5.297462
# min     764.000000   54.000000   95.000000    0.976000   88.000000
# 25%    1046.750000   88.750000  135.000000    0.982000   97.000000
# 50%    1153.000000  100.000000  147.000000    0.983000  100.000000
# 75%    1261.250000  110.000000  160.000000    0.985000  103.000000
# max    1687.000000  145.000000  204.000000    0.991000  125.000000
#
#               PPF    DivWin_Y     WCWin_Y     LgWin_Y     WSWin_Y    run_diff  \
# count  600.000000  600.000000  600.000000  600.000000  600.000000  600.000000
# mean   100.145000    0.200000    0.093333    0.066667    0.033333    0.000000
# std      5.213054    0.400334    0.291142    0.249652    0.179655  111.107116
# min     88.000000    0.000000    0.000000    0.000000    0.000000 -337.000000
# 25%     97.000000    0.000000    0.000000    0.000000    0.000000  -87.000000
# 50%    100.000000    0.000000    0.000000    0.000000    0.000000    2.000000
# 75%    103.000000    0.000000    0.000000    0.000000    0.000000   81.250000
# max    125.000000    1.000000    1.000000    1.000000    1.000000  300.000000
#
#                ba
# count  600.000000
# mean     0.259439
# std      0.012156
# min      0.226483
# 25%      0.250249
# 50%      0.259377
# 75%      0.267797
# max      0.293993

# %%
mets = df.loc[df['franchID']=='NYM']
mets.head()
# Out:
#      yearID franchID   W    R    AB     H   2B  3B   HR     BB      SO     SB  \
# 19     2000      NYM  94  807  5486  1445  281  20  198  675.0  1037.0   66.0
# 49     2001      NYM  82  642  5459  1361  273  18  147  545.0  1062.0   66.0
# 79     2002      NYM  75  690  5496  1409  238  22  160  486.0  1044.0   87.0
# 109    2003      NYM  66  642  5341  1317  262  24  124  489.0  1035.0   70.0
# 139    2004      NYM  71  684  5532  1376  289  20  185  512.0  1159.0  107.0
#
#        SF   RA   ER   ERA  CG  SHO  SV    HA  HRA  BBA   SOA    E   DP     FP  \
# 19   51.0  738  670  4.16   8   10  49  1398  164  574  1164  118  121  0.980
# 49   35.0  713  654  4.07   6   14  48  1418  186  438  1191  101  132  0.983
# 79   30.0  703  624  3.89   9   10  36  1408  163  543  1107  144  138  0.976
# 109  45.0  754  704  4.48   3   10  38  1497  168  576   907  118  158  0.980
# 139  34.0  731  658  4.09   2    6  31  1452  156  592   977  137  144  0.978
#
#      BPF  PPF  DivWin_Y  WCWin_Y  LgWin_Y  WSWin_Y  run_diff        ba
# 19    96   96         0        1        1        0        69  0.263398
# 49    96   96         0        0        0        0       -71  0.249313
# 79    97   97         0        0        0        0       -13  0.256368
# 109   97   98         0        0        0        0      -112  0.246583
# 139   99   99         0        0        0        0       -47  0.248735

# %%
df_yearly = pd.read_pickle('../data/new_df.pkl')
df_yearly.tail(10)
# Out:
#             date team  team_score  opponent_score  Hits  RBI  doubles  \
# 14564 2019-09-29  COL           4               3     8    3        0
# 14574 2019-09-29  MIN           4               5     6    4        1
# 14576 2019-09-29  ANA           5               8     8    5        4
# 14562 2019-09-29  SEA           3               1     7    3        2
# 14573 2019-09-29  DET           3               5     7    3        1
# 14573 2019-09-29  CHW           5               3     4    4        2
# 14566 2019-09-29  PHI           3               4    13    3        1
# 14563 2019-09-29  ARI           1               0     7    1        2
# 14569 2019-09-29  STL           9               0     9    8        0
# 14568 2019-09-29  LAD           9               0    12    9        1
#
#        strikeouts  def_assists  def_errors  def_doubleplays  pitchers_used  \
# 14564          15            9           1                0              8
# 14574           8            8           0                0              6
# 14576          15           10           0                0              7
# 14562           7            8           0                0              7
# 14573           8            7           1                1              4
# 14573          12           15           0                2              6
# 14566          10            7           1                1              7
# 14563           8           14           0                2              5
# 14569           7           11           0                2              3
# 14568           8           10           0                2              8
#
#        Rolling3_runs_scored  Rolling3_runs_against  Rolling3_run_diff  \
# 14564                  17.0                   17.0                0.0
# 14574                  20.0                    9.0               11.0
# 14576                   7.0                   13.0               -6.0
# 14562                   5.0                    7.0               -2.0
# 14573                   9.0                   20.0              -11.0
# 14573                  18.0                    5.0               13.0
# 14566                  17.0                   13.0                4.0
# 14563                  21.0                   15.0                6.0
# 14569                  15.0                   25.0              -10.0
# 14568                  12.0                    2.0               10.0
#
#        Rolling3_hits  Rolling3_RBI  Rolling3_doubles  Rolling3_strikeouts  \
# 14564           29.0          16.0               5.0                 32.0
# 14574           33.0          18.0               6.0                 17.0
# 14576           15.0           6.0               3.0                 27.0
# 14562           18.0           5.0               4.0                 25.0
# 14573           26.0           9.0               4.0                 31.0
# 14573           29.0          17.0               4.0                 24.0
# 14566           28.0          16.0               6.0                 32.0
# 14563           19.0          18.0               7.0                 24.0
# 14569           24.0          13.0               2.0                 36.0
# 14568           21.0          12.0               5.0                 30.0
#
#        Rolling3_def_assists  Rolling3_def_errors  Rolling3_doubleplays  \
# 14564                  33.0                  1.0                   5.0
# 14574                  12.0                  0.0                   1.0
# 14576                  29.0                  0.0                   4.0
# 14562                  27.0                  2.0                   4.0
# 14573                  17.0                  3.0                   3.0
# 14573                  30.0                  2.0                   1.0
# 14566                  38.0                  0.0                   2.0
# 14563                  27.0                  3.0                   2.0
# 14569                  25.0                  2.0                   0.0
# 14568                  16.0                  2.0                   0.0
#
#        Rolling3_pitchers_used  game_result
# 14564                    16.0            1
# 14574                    14.0            0
# 14576                    22.0            0
# 14562                    16.0            1
# 14573                    13.0            0
# 14573                    12.0            1
# 14566                    14.0            0
# 14563                    14.0            1
# 14569                    20.0            1
# 14568                    15.0            1

# %%
wins = df_yearly.loc[df_yearly['game_result']==1]
wins.describe()
# Out:
#          team_score  opponent_score          Hits           RBI       doubles  \
# count  14576.000000    14576.000000  14576.000000  14576.000000  1.457600e+04
# mean       6.199780        2.707259     10.106888      5.913625  6.973286e+05
# std        3.089897        2.048065      5.185065      3.021549  8.300032e+07
# min        1.000000        0.000000      0.000000      0.000000  0.000000e+00
# 25%        4.000000        1.000000      8.000000      4.000000  1.000000e+00
# 50%        6.000000        2.000000     10.000000      5.000000  2.000000e+00
# 75%        8.000000        4.000000     12.000000      8.000000  3.000000e+00
# max       25.000000       14.000000    259.000000     25.000000  1.002000e+10
#
#          strikeouts   def_assists    def_errors  def_doubleplays  \
# count  14576.000000  14576.000000  14576.000000     14576.000000
# mean       7.641465      9.661979      0.468716         0.923299
# std        2.888652      3.173924      0.705175         1.313298
# min        0.000000      0.000000      0.000000         0.000000
# 25%        6.000000      7.000000      0.000000         0.000000
# 50%        7.000000     10.000000      0.000000         1.000000
# 75%        9.000000     12.000000      1.000000         1.000000
# max       26.000000     28.000000      5.000000        39.000000
#
#        pitchers_used  Rolling3_runs_scored  Rolling3_runs_against  \
# count   14576.000000          14576.000000           14576.000000
# mean        4.140368             13.504871              13.169525
# std         1.428713              5.717642               5.644968
# min         0.000000              0.000000               0.000000
# 25%         3.000000              9.000000               9.000000
# 50%         4.000000             13.000000              13.000000
# 75%         5.000000             17.000000              17.000000
# max        13.000000             47.000000              42.000000
#
#        Rolling3_run_diff  Rolling3_hits  Rolling3_RBI  Rolling3_doubles  \
# count       14576.000000   14576.000000  14576.000000      1.457600e+04
# mean            0.335346      26.314215     12.890505      2.096877e+06
# std             7.835911      10.709361      5.543239      1.437509e+08
# min           -34.000000       8.000000      0.000000      0.000000e+00
# 25%            -5.000000      22.000000      9.000000      3.000000e+00
# 50%             0.000000      26.000000     12.000000      5.000000e+00
# 75%             5.000000      30.000000     16.000000      7.000000e+00
# max            32.000000     289.000000     46.000000      1.002000e+10
#
#        Rolling3_strikeouts  Rolling3_def_assists  Rolling3_def_errors  \
# count         14576.000000          14576.000000         14576.000000
# mean             24.308932             28.744649             1.747462
# std               5.724935              5.782683             1.392196
# min               7.000000             10.000000             0.000000
# 25%              20.000000             25.000000             1.000000
# 50%              24.000000             29.000000             2.000000
# 75%              28.000000             32.250000             3.000000
# max              52.000000             51.000000             9.000000
#
#        Rolling3_doubleplays  Rolling3_pitchers_used  game_result
# count          14576.000000            14576.000000      14576.0
# mean               2.701153               12.614572          1.0
# std                2.272216                2.478015          0.0
# min                0.000000                3.000000          1.0
# 25%                1.000000               11.000000          1.0
# 50%                2.000000               12.000000          1.0
# 75%                4.000000               14.000000          1.0
# max               40.000000               25.000000          1.0

# %%
losses = df_yearly.loc[df_yearly['game_result']==0]
losses.describe()
# Out:
#          team_score  opponent_score          Hits           RBI       doubles  \
# count  14578.000000    14578.000000  14578.000000  14578.000000  1.457800e+04
# mean       2.707024        6.199067      7.326931      2.589793  1.589752e+04
# std        2.048022        3.090285      5.793879      2.005121  1.185888e+06
# min        0.000000        1.000000      0.000000      0.000000  0.000000e+00
# 25%        1.000000        4.000000      5.000000      1.000000  0.000000e+00
# 50%        2.000000        6.000000      7.000000      2.000000  1.000000e+00
# 75%        4.000000        8.000000      9.000000      4.000000  2.000000e+00
# max       14.000000       25.000000    273.000000     13.000000  1.000010e+08
#
#          strikeouts   def_assists    def_errors  def_doubleplays  \
# count  14578.000000  14578.000000  14578.000000     14578.000000
# mean       8.666278      9.450473      0.700988         0.884483
# std        3.046454      3.097983      0.861453         1.264430
# min        0.000000      0.000000      0.000000         0.000000
# 25%        7.000000      7.000000      0.000000         0.000000
# 50%        8.000000      9.000000      0.000000         1.000000
# 75%       11.000000     11.000000      1.000000         1.000000
# max       26.000000     26.000000      6.000000        36.000000
#
#        pitchers_used  Rolling3_runs_scored  Rolling3_runs_against  \
# count   14578.000000          14578.000000           14578.000000
# mean        4.259569             13.222458              13.554877
# std         1.384104              5.659058               5.771831
# min         0.000000              0.000000               0.000000
# 25%         3.000000              9.000000               9.000000
# 50%         4.000000             13.000000              13.000000
# 75%         5.000000             17.000000              17.000000
# max        13.000000             46.000000              47.000000
#
#        Rolling3_run_diff  Rolling3_hits  Rolling3_RBI  Rolling3_doubles  \
# count       14578.000000   14578.000000  14578.000000      1.457800e+04
# mean           -0.332419      26.003018     12.624708      4.280236e+04
# std             7.939501       9.152148      5.487810      2.029324e+06
# min           -36.000000       6.000000      0.000000      0.000000e+00
# 25%            -5.000000      21.000000      9.000000      3.000000e+00
# 50%             0.000000      25.000000     12.000000      5.000000e+00
# 75%             5.000000      30.000000     16.000000      7.000000e+00
# max            36.000000     296.000000     44.000000      1.200221e+08
#
#        Rolling3_strikeouts  Rolling3_def_assists  Rolling3_def_errors  \
# count         14578.000000          14578.000000         14578.000000
# mean             24.597064             28.612018             1.774523
# std               5.721349              5.725978             1.399092
# min               5.000000             10.000000             0.000000
# 25%              21.000000             25.000000             1.000000
# 50%              24.000000             28.000000             2.000000
# 75%              28.000000             32.000000             3.000000
# max              50.000000             52.000000             9.000000
#
#        Rolling3_doubleplays  Rolling3_pitchers_used  game_result
# count          14578.000000            14578.000000      14578.0
# mean               2.724173               12.582110          0.0
# std                2.222727                2.454864          0.0
# min                0.000000                4.000000          0.0
# 25%                1.000000               11.000000          0.0
# 50%                2.000000               12.000000          0.0
# 75%                4.000000               14.000000          0.0
# max               42.000000               27.000000          0.0

# %%
vegas_df = pd.read_pickle('../Data/vegas_df.pkl')
vegas_df.head(10)
# Out:
#       yearID franchID    W    R    AB     H   2B  3B   HR     BB      SO  \
# 0 2017-01-01      LAD  104  770  5408  1347  312  20  221  649.0  1380.0
# 1 2014-01-01      TEX   67  637  5460  1400  260  28  111  417.0  1162.0
# 2 2015-01-01      DET   74  689  5605  1515  289  49  151  455.0  1259.0
# 3 2017-01-01      ANA   80  710  5415  1314  251  14  186  523.0  1198.0
# 4 2019-01-01      ANA   72  769  5542  1368  268  21  220  586.0  1276.0
# 5 2014-01-01      ANA   98  773  5652  1464  304  31  155  492.0  1266.0
# 6 2018-01-01      TOR   73  709  5477  1336  320  16  217  499.0  1387.0
# 7 2015-01-01      ATL   67  573  5420  1361  251  18  100  471.0  1107.0
# 8 2016-01-01      HOU   84  724  5545  1367  291  29  198  554.0  1452.0
# 9 2014-01-01      TOR   83  723  5549  1435  282  24  177  502.0  1151.0
#
#       SB    SF   RA   ER   ERA  CG  SHO  SV    HA  HRA  BBA   SOA    E   DP  \
# 0   77.0  38.0  580  543  3.38   2   16  51  1226  184  442  1549   88  131
# 1  105.0  45.0  773  711  4.49   6   17  33  1510  160  505  1110  106  155
# 2   83.0  35.0  803  746  4.64   7   12  35  1491  193  489  1100   86  165
# 3  136.0  46.0  709  672  4.20   1   10  43  1373  224  470  1312   80  135
# 4   65.0  42.0  868  820  5.12   0    2  32  1417  267  576  1404   92  118
# 5   81.0  54.0  630  590  3.58   3   13  46  1307  126  504  1342   83  127
# 6   47.0  37.0  832  772  4.85   0    3  39  1476  208  551  1298  101  138
# 7   69.0  31.0  760  698  4.41   3   10  44  1462  170  550  1148   90  186
# 8  102.0  31.0  701  663  4.06   2    8  44  1441  181  453  1396   77  135
# 9   78.0  40.0  686  642  4.00   3   16  45  1400  151  490  1199   87  130
#
#       FP  BPF  PPF  DivWin_Y  WCWin_Y  LgWin_Y  WSWin_Y  run_diff        ba  \
# 0  0.985   97   96         1        0        1        0       190  0.249075
# 1  0.982  101  101         0        0        0        0      -136  0.256410
# 2  0.986   97   98         0        0        0        0      -114  0.270294
# 3  0.986   96   96         0        0        0        0         1  0.242659
# 4  0.984   98   98         0        0        0        0       -99  0.246842
# 5  0.986   96   95         1        0        0        0       143  0.259023
# 6  0.983   97   98         0        0        0        0      -123  0.243929
# 7  0.985   97   97         0        0        0        0      -187  0.251107
# 8  0.987   90   89         0        0        0        0        23  0.246528
# 9  0.985  102  102         0        0        0        0        37  0.258605
#
#    vegas_win_total  abs_line_accuracy  pdiff_line_accuracy
# 0             93.5               10.5             0.112299
# 1             87.0              -20.0            -0.229885
# 2             84.5              -10.5            -0.124260
# 3             79.5                0.5             0.006289
# 4             83.5              -11.5            -0.137725
# 5             87.0               11.0             0.126437
# 6             81.5               -8.5            -0.104294
# 7             73.5               -6.5            -0.088435
# 8             87.5               -3.5            -0.040000
# 9             80.5                2.5             0.031056

# %%
vegas_df_2019 = vegas_df.loc[vegas_df['yearID']=='2019-01-01']
vegas_df_2018 = vegas_df.loc[vegas_df['yearID']=='2018-01-01']
vegas_df_2017 = vegas_df.loc[vegas_df['yearID']=='2017-01-01']
vegas_df_2016 = vegas_df.loc[vegas_df['yearID']=='2016-01-01']
vegas_df_2015 = vegas_df.loc[vegas_df['yearID']=='2015-01-01']
vegas_df_2014 = vegas_df.loc[vegas_df['yearID']=='2014-01-01']

# %%
cols = ['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO',
       'SB', 'SF', 'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'HA', 'HRA', 'BBA',
       'SOA', 'E', 'DP', 'FP', 'BPF', 'PPF', 'DivWin_Y', 'WCWin_Y', 'LgWin_Y',
       'WSWin_Y', 'run_diff', 'ba']
vegas_df.drop(cols, axis=1, inplace=True)

# %%
vegas_df.sort_values('yearID', ascending=True)
# Out:
#         yearID franchID    W  vegas_win_total  abs_line_accuracy  \
# 89  2014-01-01      CHC   73             69.5                3.5
# 78  2014-01-01      ATL   79             87.5               -8.5
# 142 2014-01-01      STL   90             91.5               -1.5
# 41  2014-01-01      ARI   64             80.5              -16.5
# 128 2014-01-01      WSN   96             89.5                6.5
# ..         ...      ...  ...              ...                ...
# 153 2019-01-01      LAD  106             95.0               11.0
# 125 2019-01-01      TBD   96             85.5               10.5
# 123 2019-01-01      NYY  103             94.5                8.5
# 130 2019-01-01      WSN   93             88.5                4.5
# 36  2019-01-01      BOS   84             95.5              -11.5
#
#      pdiff_line_accuracy
# 89              0.050360
# 78             -0.097143
# 142            -0.016393
# 41             -0.204969
# 128             0.072626
# ..                   ...
# 153             0.115789
# 125             0.122807
# 123             0.089947
# 130             0.050847
# 36             -0.120419
#
# [180 rows x 6 columns]

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(6, sharex=True, sharey=True, figsize=(22,14))
fig.suptitle('MLB Season Total Wins: Actual vs. Vegas Line', fontsize=22)
fig.text(0.5,0.04, "Teams", ha="center", va="center", fontsize=14)
fig.text(0.05,0.5, "Season Total Wins", ha="center", va="center", rotation=90, fontsize=14)

X = vegas_df_2019['franchID']
y = vegas_df_2019['W']
z = vegas_df_2019['vegas_win_total']

w = vegas_df_2018['W']
b = vegas_df_2018['vegas_win_total']

v = vegas_df_2017['W']
c = vegas_df_2017['vegas_win_total']

u = vegas_df_2016['W']
d = vegas_df_2016['vegas_win_total']

t = vegas_df_2015['W']
e = vegas_df_2015['vegas_win_total']

s = vegas_df_2014['W']
f = vegas_df_2014['vegas_win_total']

ax1.plot(X, y, color='navy', label='Actual Wins')
ax1.plot(X, z, color='red', label='Vegas Line')

ax2.plot(X, w, color='navy', label='Actual Wins')
ax2.plot(X, b, color='red', label='Vegas Line')

ax3.plot(X, v, color='navy', label='Actual Wins')
ax3.plot(X, c, color='red', label='Vegas Line')

ax4.plot(X, u, color='navy', label='Actual Wins')
ax4.plot(X, d, color='red', label='Vegas Line')

ax5.plot(X, t, color='navy', label='Actual Wins')
ax5.plot(X, e, color='red', label='Vegas Line')

ax6.plot(X, s, color='navy', label='Actual Wins')
ax6.plot(X, f, color='red', label='Vegas Line')

ax1.set_title('2019', fontsize=14)
ax2.set_title('2018', fontsize=14)
ax3.set_title('2017', fontsize=14)
ax4.set_title('2016', fontsize=14)
ax5.set_title('2015', fontsize=14)
ax6.set_title('2014', fontsize=14)

ax1.legend(fontsize='medium', loc='upper left')
plt.show()
plt.savefig('../Images_and_Analysis/VegasAccuracy_SeasonTotalWins.png')

# %% [markdown]
# As you can see, vegas is EXTREMELY accurate! In fact, when I compiled the data by team, cumulative of the years 2014 - 2019, the vegas lines for season total wins for each team were staggeringly accurate. Over this 6 year period, only 5 teams had a more than 5% difference when comparing the vegas line to the actual season total wins from that same year.

# %% [markdown]
# # SQL

# %% [markdown]
# set batch_id = '22092029' ;
# set bench_table = concat('table_name_', $batch_id) ;
#
# proj_factors2 as (
# select
#     p.proj_factor,
#     p.eligibility,
#     d.*
# from proj_factor1 as p
#     left join demos as d
#     on p.userID = d.userID )
