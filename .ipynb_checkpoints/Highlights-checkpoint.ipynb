# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pickle
sns.set_theme(style="whitegrid")

# %%
df = pd.read_pickle('data/yearly_df.pkl')
df.head(10)
# Out:
#    yearID franchID    W    R    AB     H   2B  3B   HR     BB  ...  DivWin_Y  \
# 0    2017      STL   83  761  5470  1402  284  28  196  593.0  ...         0
# 1    2015      MIL   68  655  5480  1378  274  34  145  412.0  ...         0
# 2    2017      ARI   93  812  5525  1405  314  39  220  578.0  ...         0
# 3    2019      ANA   72  769  5542  1368  268  21  220  586.0  ...         0
# 4    2017      ANA   80  710  5415  1314  251  14  186  523.0  ...         0
# 5    2019      ARI   85  813  5633  1419  288  40  220  540.0  ...         0
# 6    2018      BAL   47  622  5507  1317  242  15  188  422.0  ...         0
# 7    2017      LAD  104  770  5408  1347  312  20  221  649.0  ...         1
# 8    2016      SDP   68  686  5419  1275  257  26  177  449.0  ...         0
# 9    2018      TOR   73  709  5477  1336  320  16  217  499.0  ...         0
#
#    WCWin_Y  LgWin_Y  WSWin_Y  run_diff        ba  linedrivepercent   xobp  \
# ...

# %%
df.describe()
# Out:
#             yearID           W           R           AB            H  \
# count   150.000000  150.000000  150.000000   150.000000   150.000000
# mean   2017.000000   80.973333  733.800000  5524.660000  1397.693333
# std       1.418951   12.675054   76.678532    71.727376    67.263475
# min    2015.000000   47.000000  573.000000  5330.000000  1251.000000
# 25%    2016.000000   71.000000  680.500000  5478.250000  1349.250000
# 50%    2017.000000   81.000000  729.000000  5520.500000  1392.000000
# 75%    2018.000000   91.000000  773.250000  5566.500000  1441.500000
# max    2019.000000  108.000000  943.000000  5770.000000  1598.000000
#
#                2B          3B          HR          BB           SO  ...  \
# count  150.000000  150.000000  150.000000  150.000000   150.000000  ...
# mean   277.920000   28.260000  193.233333  510.473333  1337.080000  ...
# std     25.641964    9.395437   38.930573   67.462910   126.072075  ...
# ...

# %%
mets = df.loc[df['franchID']=='NYM']
mets.head()
# Out:
#      yearID franchID   W    R    AB     H   2B  3B   HR     BB  ...  DivWin_Y  \
# 11     2018      NYM  77  676  5468  1282  265  34  170  566.0  ...         0
# 26     2017      NYM  70  735  5510  1379  286  28  224  529.0  ...         0
# 72     2016      NYM  87  671  5459  1342  240  19  218  517.0  ...         0
# 118    2015      NYM  90  683  5527  1351  295  17  177  488.0  ...         1
# 134    2019      NYM  86  791  5624  1445  280  17  242  516.0  ...         0
#
#      WCWin_Y  LgWin_Y  WSWin_Y  run_diff        ba  linedrivepercent   xobp  \
# 11         0        0        0       -31  0.234455              23.4  0.307
# 26         0        0        0      -128  0.250272              24.5  0.316
# 72         1        0        0        54  0.245833              26.5  0.314
# 118        0        1        0        70  0.244436              26.8  0.310
# 134        0        0        0        54  0.256935              25.4  0.322
#
#      xwoba  vegas_win_total
# ...

# %%
mets.sort_values(by='R', ascending=True, axis=1)
mets.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-887dc92aef89> in <module>
# ----> 1 mets.sort_values(by='R', ascending=True, axis=1)
#       2 mets.head()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    5006
#    5007             by = by[0]
# -> 5008             k = self._get_label_or_level_values(by, axis=axis)
#    5009
#    5010             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'R'
